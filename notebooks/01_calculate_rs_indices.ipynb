# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.workflow import workflow

from main import INDEX_NAMES, DIR_PARIKA, DIR_ILMATSALU

# %%
red_path_parika = r"..\data\raster\Parika\band_red.tif"
green_path_parika = r"..\data\raster\Parika\band_green.tif"
nir_path_parika = r"..\data\raster\Parika\band_nir.tif"
red_edge_path_parika = r"..\data\raster\Parika\band_red_edge.tif"

red_path_Ilmatsalu = r"..\data\raster\Ilmatsalu\drone_imagery\band_red.tif"
green_path_Ilmatsalu = r"..\data\raster\Ilmatsalu\drone_imagery\band_green.tif"
nir_path_Ilmatsalu = r"..\data\raster\Ilmatsalu\drone_imagery\band_nir.tif"
red_edge_path_Ilmatsalu = r"..\data\raster\Ilmatsalu\drone_imagery\band_redge.tif"

red_path_Ilmatsalu_S2 = r"..\data\raster\Ilmatsalu\sentinel-2\red_band_sentinel_2.tif"
green_path_Ilmatsalu_S2 = r"..\data\raster\Ilmatsalu\sentinel-2\green_band_sentinel_2.tif"
nir_path_Ilmatsalu_S2 = r"..\data\raster\Ilmatsalu\sentinel-2\NIR_band_sentinel_2.tif"
red_edge_path_Ilmatsalu_S2 = r"..\data\raster\Ilmatsalu\sentinel-2\red_edge_band_sentinel_2_resampled.tif"

red_path_Parika_S2 = r"..\data\raster\Parika\sentinel-2\red_band_sentinel_2.tif"
green_path_Parika_S2 = r"..\data\raster\Parika\sentinel-2\green_band_sentinel_2.tif"
nir_path_Parika_S2 = r"..\data\raster\Parika\sentinel-2\NIR_band_sentinel_2.tif"
red_edge_path_Parika_S2 = r"..\data\raster\Parika\sentinel-2\red_edge_band_sentinel_2_resampled.tif"

# %%
indices = workflow(red_path_Ilmatsalu,
                   green_path_Ilmatsalu, 
                   nir_path_Ilmatsalu, 
                   red_edge_path_Ilmatsalu, 
                   DIR_ILMATSALU, 
                   index_names=INDEX_NAMES,
                   src_img="drone_img")

indices = workflow(red_path_parika,
                   green_path_parika, 
                   nir_path_parika, 
                   red_edge_path_parika, 
                   DIR_PARIKA, 
                   index_names=INDEX_NAMES,
                   src_img="drone_img")

# %%
indices = workflow(red_path_Ilmatsalu_S2,
                   green_path_Ilmatsalu_S2, 
                   nir_path_Ilmatsalu_S2, 
                   red_edge_path_Ilmatsalu_S2, 
                   DIR_ILMATSALU, 
                   index_names=INDEX_NAMES,
                   src_img="S2")

indices = workflow(red_path_Parika_S2,
                   green_path_Parika_S2, 
                   nir_path_Parika_S2, 
                   red_edge_path_Parika_S2, 
                   DIR_PARIKA, 
                   index_names=INDEX_NAMES,
                   src_img="S2")
