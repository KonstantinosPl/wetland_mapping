# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.geospatial import raster2points
from src.plots import plot_correlation_heatmap

from main import DIR_ILMATSALU_INDICES, DIR_PARIKA_INDICES, OUTPUT_DIR_PLOTS, REGION_NAME_ILMATSALU, REGION_NAME_PARIKA

# %%
output_dir = r"..\results\Ilmatsalu\points"
raster2points(input_dir=DIR_ILMATSALU_INDICES, output_dir=output_dir)

input_path = r"..\results\Ilmatsalu\points\rs_indices_points.parquet"
plot_correlation_heatmap(input_path_data=input_path, output_dir=OUTPUT_DIR_PLOTS, region_name=REGION_NAME_ILMATSALU)

# %%
output_dir = r"..\results\Parika\points"
raster2points(input_dir=DIR_PARIKA_INDICES, output_dir=output_dir)

input_path = r"..\results\Parika\points\rs_indices_points.parquet"
plot_correlation_heatmap(input_path_data=input_path, output_dir=OUTPUT_DIR_PLOTS, region_name=REGION_NAME_PARIKA)
