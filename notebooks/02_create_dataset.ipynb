# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.geospatial import raster2points
from src.plots import plot_correlation_heatmap

from main import DIR_ILMATSALU, DIR_PARIKA, OUTPUT_DIR_PLOTS, REGION_NAME_ILMATSALU, REGION_NAME_PARIKA, DIR_PARIKA_INDICES_DRONE, DIR_ILMATSALU_INDICES_DRONE, DIR_PARIKA_INDICES_S2, DIR_ILMATSALU_INDICES_S2, SRC_IMG_S2_NAME, SRC_IMG_DRONE_NAME

# %%
raster2points(input_dir=DIR_ILMATSALU_INDICES_DRONE, 
              output_dir=DIR_ILMATSALU, 
              src_img=SRC_IMG_DRONE_NAME)

input_path = r"..\results\Ilmatsalu\drone_img\points\rs_indices_points.parquet"
plot_correlation_heatmap(input_path_data=input_path, 
                         output_dir=OUTPUT_DIR_PLOTS, 
                         region_name=REGION_NAME_ILMATSALU,
                         src_img=SRC_IMG_DRONE_NAME 
                         )

# %%
raster2points(input_dir=DIR_PARIKA_INDICES_DRONE, 
              output_dir=DIR_PARIKA,
              src_img=SRC_IMG_DRONE_NAME)

input_path = r"..\results\Parika\drone_img\points\rs_indices_points.parquet"
plot_correlation_heatmap(input_path_data=input_path, 
                         output_dir=OUTPUT_DIR_PLOTS, 
                         region_name=REGION_NAME_PARIKA,
                         src_img=SRC_IMG_DRONE_NAME)

# %%
raster2points(input_dir=DIR_PARIKA_INDICES_S2, 
              output_dir=DIR_PARIKA,
              src_img=SRC_IMG_S2_NAME)

input_path = r"..\results\Parika\S2\points\rs_indices_points.parquet"
plot_correlation_heatmap(input_path_data=input_path, 
                         output_dir=OUTPUT_DIR_PLOTS, 
                         region_name=REGION_NAME_PARIKA,
                         src_img=SRC_IMG_S2_NAME)

# %%
raster2points(input_dir=DIR_ILMATSALU_INDICES_S2, 
              output_dir=DIR_ILMATSALU,
              src_img=SRC_IMG_S2_NAME)

input_path = r"..\results\Ilmatsalu\S2\points\rs_indices_points.parquet"
plot_correlation_heatmap(input_path_data=input_path, 
                         output_dir=OUTPUT_DIR_PLOTS, 
                         region_name=REGION_NAME_ILMATSALU,
                         src_img=SRC_IMG_S2_NAME)
