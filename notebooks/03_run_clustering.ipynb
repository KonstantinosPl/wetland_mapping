# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.modelling import clustering

from main import DIR_ILMATSALU, DIR_PARIKA, SRC_IMG_DRONE_NAME, SRC_IMG_S2_NAME

# %%
input_points_parika_drone = r"..\results\Parika\drone_img\points\rs_indices_points.parquet"
input_points_ilmatsalu_drone = r"..\results\Ilmatsalu\drone_img\points\rs_indices_points.parquet"

clustering(input_points_parika_drone, DIR_PARIKA, src_img=SRC_IMG_DRONE_NAME)
clustering(input_points_ilmatsalu_drone, DIR_ILMATSALU, src_img=SRC_IMG_DRONE_NAME)

# %%
input_points_ilmatsalu_S2 = r"..\results\Ilmatsalu\S2\points\rs_indices_points.parquet"
input_points_parika_S2 = r"..\results\Parika\S2\points\rs_indices_points.parquet"

clustering(input_points_ilmatsalu_S2, DIR_ILMATSALU, src_img=SRC_IMG_S2_NAME)
clustering(input_points_parika_S2, DIR_PARIKA, src_img=SRC_IMG_S2_NAME)
# Out:
# Best number of clusters: 4
