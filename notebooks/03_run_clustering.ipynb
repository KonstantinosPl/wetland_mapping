# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.modelling import clustering

from main import DIR_ILMATSALU, DIR_PARIKA

# %%
input_points_parika = r"..\results\Parika\points\rs_indices_points.parquet"
input_points_ilmatsalu = r"..\results\Ilmatsalu\points\rs_indices_points.parquet"

clustering(input_points_parika, DIR_PARIKA)
clustering(input_points_ilmatsalu, DIR_ILMATSALU)
