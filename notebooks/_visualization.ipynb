# %%
import sys
from pathlib import Path
import os

project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.plots import plot_hist_index

from main import INDEX_NAMES, DIR_ILMATSALU, DIR_PARIKA, REGION_NAME_PARIKA, OUTPUT_DIR_PLOTS

# %%
tif_paths_Ilmatsalu = {
    index.upper(): os.path.join(DIR_ILMATSALU, f"{index}.tif")
    for index in INDEX_NAMES
}

tif_paths_Parika = {
    index.upper(): os.path.join(DIR_PARIKA, f"{index}.tif")
    for index in INDEX_NAMES
}

boundaries_path_ilmatsalu = r"..\data\vector\boundaries_peatAbandoned.geojson"

# %%
plot_hist_index(tif_paths=tif_paths_Parika, output_dir=OUTPUT_DIR_PLOTS, region_name=REGION_NAME_PARIKA, boundaries_path=None)
plot_hist_index(tif_paths=tif_paths_Ilmatsalu, output_dir=OUTPUT_DIR_PLOTS, region_name=REGION_NAME_PARIKA, boundaries_path=boundaries_path_ilmatsalu)
